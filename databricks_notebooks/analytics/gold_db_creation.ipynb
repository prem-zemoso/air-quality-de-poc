# %%
# %sql
CREATE SCHEMA IF NOT EXISTS aqi_gold;

# %%
# %sql


--  DIM LOCATION
DROP TABLE IF EXISTS adb_air_quality_poc.aqi_gold.dim_location;

CREATE TABLE adb_air_quality_poc.aqi_gold.dim_location
USING DELTA
AS
SELECT *
FROM delta.`abfss://gold@adlsairqualitypoc.dfs.core.windows.net/aqi/dim_location`;


-- DIM POLLUTANT
DROP TABLE IF EXISTS adb_air_quality_poc.aqi_gold.dim_pollutant;

CREATE TABLE adb_air_quality_poc.aqi_gold.dim_pollutant
USING DELTA
AS
SELECT *
FROM delta.`abfss://gold@adlsairqualitypoc.dfs.core.windows.net/aqi/dim_pollutant`;


--  DIM DATE
DROP TABLE IF EXISTS adb_air_quality_poc.aqi_gold.dim_date;

CREATE TABLE adb_air_quality_poc.aqi_gold.dim_date
USING DELTA
AS
SELECT *
FROM delta.`abfss://gold@adlsairqualitypoc.dfs.core.windows.net/aqi/dim_date`;


-- FACT AIR QUALITY
DROP TABLE IF EXISTS adb_air_quality_poc.aqi_gold.fact_air_quality;

CREATE TABLE adb_air_quality_poc.aqi_gold.fact_air_quality
USING DELTA
AS
SELECT *
FROM delta.`abfss://gold@adlsairqualitypoc.dfs.core.windows.net/aqi/fact_air_quality`;


-- DAILY STATE AGG
DROP TABLE IF EXISTS adb_air_quality_poc.aqi_gold.agg_daily_state;

CREATE TABLE adb_air_quality_poc.aqi_gold.agg_daily_state
USING DELTA
AS
SELECT *
FROM delta.`abfss://gold@adlsairqualitypoc.dfs.core.windows.net/aqi/agg_daily_state`;


-- DAILY CITY AGG
DROP TABLE IF EXISTS adb_air_quality_poc.aqi_gold.agg_daily_city;

CREATE TABLE adb_air_quality_poc.aqi_gold.agg_daily_city
USING DELTA
AS
SELECT *
FROM delta.`abfss://gold@adlsairqualitypoc.dfs.core.windows.net/aqi/agg_daily_city`;


-- HOURLY STATE AGG
DROP TABLE IF EXISTS adb_air_quality_poc.aqi_gold.agg_hourly_state;

CREATE TABLE adb_air_quality_poc.aqi_gold.agg_hourly_state
USING DELTA
AS
SELECT *
FROM delta.`abfss://gold@adlsairqualitypoc.dfs.core.windows.net/aqi/agg_hourly_state`;


-- THRESHOLD BREACH FACT
DROP TABLE IF EXISTS adb_air_quality_poc.aqi_gold.fact_threshold_breach;

CREATE TABLE adb_air_quality_poc.aqi_gold.fact_threshold_breach
USING DELTA
AS
SELECT *
FROM delta.`abfss://gold@adlsairqualitypoc.dfs.core.windows.net/aqi/fact_threshold_breach`;
